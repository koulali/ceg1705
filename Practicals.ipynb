# %% [markdown]
# ![img](./img/ceg1705_logo_notebook.png)
#
# #  PRACTICAL NOTEBOOKS
#
#
#
# These notebooks include practical sessions on computational aspects of coordinate systems (**Practical 1 and 3**) and one practical field exercise involving the collection of actual GNSS data, followed by analysis and interpretation of errors (**Practical 2**).
#
#
#
# ### [Practical 1](Practical1.ipynb) (coordinate types): 4% for satisfactory completion;
#
# ### [Practical 2](Practical2.ipynb) (GNSS in the field): 3% for satisfactory completion of fieldwork and seminar;
#
# ### [Practical 3](Practical3.ipynb) (coordinate transformations): 8% for satisfactory completion and correct calculations;
